# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# read data
df = pd.read_csv('Student_performance_data _.csv')

# %% [markdown]
# # Describe statistic of feature

# %%
print(df.head(5))
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df['Age'].describe()
# Out:
# count    2392.000000
# mean       16.468645
# std         1.123798
# min        15.000000
# 25%        15.000000
# 50%        16.000000
# 75%        17.000000
# max        18.000000
# Name: Age, dtype: float64

# %%
df['Ethnicity'].describe()
# Out:
# count    2392.000000
# mean        0.877508
# std         1.028476
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max         3.000000
# Name: Ethnicity, dtype: float64

# %%
df['GPA'].describe()
# Out:
# count    2392.000000
# mean        1.906186
# std         0.915156
# min         0.000000
# 25%         1.174803
# 50%         1.893393
# 75%         2.622216
# max         4.000000
# Name: GPA, dtype: float64

# %%
# Scatter plot GPA and ParentalSupport
# sns.scatterplot(data=df, x='GPA', y='GradeClass', color='blue')
plt.scatter(df['GPA'], df['ParentalSupport'], color='blue', edgecolor='black',)
plt.title('Scatter plot GPA and ParentalSupport')
plt.xlabel('GPA')
plt.ylabel('ParentalSupport')
plt.show()

# %%
# Scatter plot Absences and GPA
# sns.scatterplot(data=df, x='GPA', y='GradeClass', color='blue')
plt.scatter(df['GPA'], df['Absences'], color='blue', edgecolor='black',)
plt.title('Scatter plot Absences and GPA')
plt.xlabel('GPA')
plt.ylabel('Absences')
plt.show()

# %%
# Scatter plot ParentalEducation and GPA
# sns.scatterplot(data=df, x='GPA', y='GradeClass', color='blue')
plt.scatter(df['GPA'], df['ParentalEducation'], color='blue', edgecolor='black',)
plt.title('Scatter plot GPA and ParentalEducation')
plt.xlabel('GPA')
plt.ylabel('ParentalEducation')
plt.show()

# %%
# Scatter plot StudyTimeWeekly and GPA
plt.scatter(df['GPA'], df['StudyTimeWeekly'], color='blue', edgecolor='black',)
plt.title('Scatter plot GPA and StudyTimeWeekly')
plt.xlabel('GPA')
plt.ylabel('StudyTimeWeekly')
plt.show()

# %%
# Scatter plot Tutoring and GPA
plt.scatter(df['Tutoring'], df['GPA'], color='blue', edgecolor='black', s=20, alpha=0.5)

plt.title('Scatter plot GPA and Tutoring')
plt.xlabel('Tutoring')
plt.ylabel('GPA')
# plt.plot(np.unique(df['Tutoring']), np.poly1d(np.polyfit(df['Tutoring'], df['GPA'], 1))(np.unique(df['Tutoring'])), color='red')
plt.show()

# %%
# Scatter plot Tutoring and GPA
plt.scatter( df['GPA'], df['Extracurricular'], color='blue', edgecolor='black', s=20, alpha=0.5)

plt.title('Scatter plot GPA and Extracurricular')
plt.xlabel('GPA')
plt.ylabel('Extracurricular')
# plt.plot(np.unique(df['Tutoring']), np.poly1d(np.polyfit(df['Tutoring'], df['GPA'], 1))(np.unique(df['Tutoring'])), color='red')
plt.show()

# %%
# Try to use 
cols = ['StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport', 'GPA']
df_pair = df[cols]
sns.pairplot(df_pair, hue='Tutoring')
plt.show()
